# %%
#2.9
print("섭씨\t화씨")
for celsius in range(0,60,10):
    fahrenheit=(9/5)*celsius+32
    print(celsius,"\t",fahrenheit)

#2.10
print("--------------------------------")
temp=int(input("섭씨온도를 입력하세요 : "))
fa=(9/5)*temp+32
print("섭씨",temp,"도는 화씨 ",fa,"도 입니다")

#2.12
print("--------------------------------")
PI=3.141592
radius=11
circumference=radius*2*PI
area=radius**2*PI
print("원의 반지름 : ",radius,"원의 둘레 : ",circumference,\
    "원의 면적 : ",area)

#2.14
print("--------------------------------")
for i in range(1,11):
    print(i,"의 제곱근 = ",i**0.5)

#2.16
print("--------------------------------")
import math
print("1) 회전하기 전 : 1+2j")
coordinate=(1+2j)*(0+1j)
print("90도 회전한 후 : ",coordinate)
print("2) 회전하기 전 : 1+2j")
coordinate=(1+2j)*(math.sqrt(3)/2 + 1j/2)
print("30도 회전한 후 : ",coordinate)

#2.17
print("--------------------------------")
for i in range(10):
    print(2<<i)

#2.20
print("--------------------------------")
print(bin(5),"&",bin(6),"=",bin(5&6))
print(bin(5),"|",bin(6),"=",bin(5|6))
print(bin(5),"^",bin(6),"=",bin(5^6))

#2.21
print("--------------------------------")
num = int(input("정수를 입력하시오 : "))
print(num,"의 2진수 값 : ",bin(num))
print(num,"의 2진수 값에 대한 비트단위 부정값 : ",bin(~num))

#2.23
print("--------------------------------")
num = int(input("세 자리 정수를 입력하세요 : "))
print("백의 자리 :",num//100)
num=num%100
print("십의 자리 :",num//10)
num=num%10
print("일의 자리 :",num)

#2.24
print("--------------------------------")
num = int(input("세 자리 정수를 입력하세요 : "))
for _ in range(3):
    print(num%10)
    num=num//10
# Out:
# 섭씨	화씨
# 0 	 32.0
# 10 	 50.0
# 20 	 68.0
# 30 	 86.0
# 40 	 104.0
# 50 	 122.0
# --------------------------------
# 섭씨온도를 입력하세요 : 30
# 섭씨 30 도는 화씨  86.0 도 입니다
# --------------------------------
# 원의 반지름 :  11 원의 둘레 :  69.115024 원의 면적 :  380.132632
# --------------------------------
# 1 의 제곱근 =  1.0
# 2 의 제곱근 =  1.4142135623730951
# 3 의 제곱근 =  1.7320508075688772
# 4 의 제곱근 =  2.0
# 5 의 제곱근 =  2.23606797749979
# 6 의 제곱근 =  2.449489742783178
# 7 의 제곱근 =  2.6457513110645907
# 8 의 제곱근 =  2.8284271247461903
# 9 의 제곱근 =  3.0
# 10 의 제곱근 =  3.1622776601683795
# --------------------------------
# 1) 회전하기 전 : 1+2j
# 90도 회전한 후 :  (-2+1j)
# 2) 회전하기 전 : 1+2j
# 30도 회전한 후 :  (-0.1339745962155614+2.232050807568877j)
# --------------------------------
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# --------------------------------
# 0b101 & 0b110 = 0b100
# 0b101 | 0b110 = 0b111
# 0b101 ^ 0b110 = 0b11
# --------------------------------
# 정수를 입력하시오 : 4
# 4 의 2진수 값 :  0b100
# ...
